# %%
import pandas as pd

# %%
df = pd.read_csv('../data/SEA_training_data.csv')
df['label'] = pd.read_csv('../data/SEA_training_class.csv', header=None).iloc[:, 0]

# %%
df.describe()

# %%
df['label'].unique()
