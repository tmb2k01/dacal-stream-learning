# %%
import pandas as pd

# %%
df = pd.read_csv('../data/SEA_training_data.csv')
df['label'] = pd.read_csv('../data/SEA_training_class.csv')

# %%
df.describe()
# Out:
#              9.4191        1.1647        4.4388         label
# count  49999.000000  49999.000000  49999.000000  49999.000000
# mean       5.014195      5.005731      4.967998      0.380968
# std        2.888207      2.888992      2.887407      0.485629
# min        0.000106      0.000286      0.000058      0.000000
# 25%        2.519600      2.493700      2.443700      0.000000
# 50%        5.029700      5.008900      4.985300      0.000000
# 75%        7.504000      7.502050      7.447900      1.000000
# max        9.999600     10.000000     10.000000      1.000000

# %%
df['label'].unique()
# Out:
# array([1, 0])
